# %%
import pandas as pd

# %%
'''This function will load the Excel dataset in this function we try to use only Pandas to manipulate our data'''
data = pd.DataFrame()
address = 'G:\Google\Electronic Design\python_projects\Product Price Dashboard\prices.xls'
'''Specifying the headers and index column actually will help alot to search the file easier.'''
data = pd.read_excel(address,
                         sheet_name="ref",
                         header=0,
                         index_col=0)

# %%
data
# Out:
#                           Item   Size    Price
# Type
# Pistachio                   AA  20-22  1700000
# Pistachio                   AA  22-24  1800000
# Pistachio                   AA  24-26  1900000
# Pistachio                   AA  26-28  1930000
# Pistachio                Jumbo  20-22  1700000
# Pistachio                Jumbo  22-24  1750000
# Pistachio                Jumbo  24-26  1780000
# Pistachio                Jumbo  26-28  1800000
# Pistachio                Round  28-30  1790000
# Pistachio                Round  30-32  1850000
# Pistachio                Round  32-34  1900000
# Pistachio                Round  34-36  1720000
# Pistachio           AK S. Long  18-20  1950000
# Pistachio           AK S. Long  20-22  1950000
# Pistachio           AK S. Long  22-24  1950000
# Pistachio           AK S. Long  24-26  1950000
# Pistachio           AK S. Long  24-26  1950000
# Closed Mouth             AA CM  24-26  1700000
# Closed Mouth          Jumbo CM  22-24  1700000
# Closed Mouth          Round CM  30-32  1700000
# Closed Mouth  AK Super Long CM  22-24  1700000
# Kernel                      AA  24-26  3500000
# Kernel                   Jumbp  22-24  3500000
# Kernel                   Round  30-32  3500000
# Kernel              AK S. Long  22-24  3500000

# %%
info = data[['Type', 'Item', 'Size', 'Price']]
info = info.dropna()
info = info.drop_duplicates()
#Contacts = Contacts.set_index('Name')

# %%
Contacts.to_csv('G:\Google\Electronic Design\python_projects\Insight of Ecommerce Data\Contacts.csv')
